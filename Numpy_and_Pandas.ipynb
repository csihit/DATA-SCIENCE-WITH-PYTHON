# %% [markdown]
# <a href="https://colab.research.google.com/github/Aadi1039/Data-Science-with-Python/blob/main/Numpy_and_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
df=pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import numpy as np
import pandas as pd
data= [1,['a',3],4,[5,'b'],7]
df=pd.DataFrame(data)
print(df)
# Out:
#         0
# 0       1
# 1  [a, 3]
# 2       4
# 3  [5, b]
# 4       7

# %%
import numpy as np
import pandas as pd
data=[['Aditya',67],['Virat',76],['Krishu',91]]
df=pd.DataFrame(data,columns=['Name','Aggregate'])
print(df)
# Out:
#      Name  Aggregate
# 0  Aditya         67
# 1   Virat         76
# 2  Krishu         91

# %%
import numpy as np
import pandas as pd
data1={'Name':['Aditya','Virat','Krishu'],'Age':[22,21,20]}
data2={'Name':['Aditya','Virat','aryan'],'Marks':[80,81,82]}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
print(df1)
print(df2)
# Out:
#      Name  Age
# 0  Aditya   22
# 1   Virat   21
# 2  Krishu   20
#      Name  Marks
# 0  Aditya     80
# 1   Virat     81
# 2   aryan     82

# %%
import numpy as np
import pandas as pd
data=[{'Name':'Aditya','Marks':90},{'Name':'Virat','Marks':89},{'Name':'Krishu','Marks':88}]
df=pd.DataFrame(data, index=['stud1','stud2','stud3'])
print(df)
# Out:
#          Name  Marks
# stud1  Aditya     90
# stud2   Virat     89
# stud3  Krishu     88

# %%
import numpy as np
import pandas as pd

data={
    'Aditya':pd.Series([80,90,91],index=['M1','M2','M3']),
    'Virat':pd.Series([80,90,91,92],index=['M1','M2','M3','M4'])
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Aditya  Virat
# M1    80.0     80
# M2    90.0     90
# M3    91.0     91
# M4     NaN     92

# %%
name= input("enter the name of the students whose marks you want to see:")
print(df[name])
# Out:
# enter the name of the students whose marks you want to see:Virat
# M1    80
# M2    90
# M3    91
# M4    92
# Name: Virat, dtype: int64

# %%
df['Krishu']=pd.Series([80,81,82],index=['M1','M2','M3'])
print(df)
# Out:
#     Aditya  Virat  Krishu
# M1    80.0     80    80.0
# M2    90.0     90    81.0
# M3    91.0     91    82.0
# M4     NaN     92     NaN

# %%
name= input("enter the name of the students whose marks you want to see:")
print(df[name])
# Out:
# enter the name of the students whose marks you want to see:Virat
# M1    80
# M2    90
# M3    91
# M4    92
# Name: Virat, dtype: int64

# %%
import numpy as np
import pandas as pd

data={
    'Aditya':pd.Series([80,90,91],index=['M1','M2','M3']),
    'Virat':pd.Series([80,90,91,92],index=['M1','M2','M3','M4']),
    'Krishu':pd.Series([80,81,82],index=['M1','M2','M3']),
    'Mahi':pd.Series([80,90,91,92],index=['M1','M2','M3','M4'])
}
df=pd.DataFrame(data)
print(df)
#deleting a column
del df['Virat']
print(df)
df.pop('Mahi')
print(df)
del df['Krishu']
print(df)
# Out:
#     Aditya  Virat  Krishu  Mahi
# M1    80.0     80    80.0    80
# M2    90.0     90    81.0    90
# M3    91.0     91    82.0    91
# M4     NaN     92     NaN    92
#     Aditya  Krishu  Mahi
# M1    80.0    80.0    80
# M2    90.0    81.0    90
# M3    91.0    82.0    91
# M4     NaN     NaN    92
#     Aditya  Krishu
# M1    80.0    80.0
# M2    90.0    81.0
# M3    91.0    82.0
# M4     NaN     NaN
#     Aditya
# M1    80.0
# M2    90.0
# M3    91.0
# M4     NaN

# %%
import numpy as np
import pandas as pd
data={
    'Name':['Aditya','Virat','Krishu','Mahi'],
    'Age':[12,13,14,15],
    'interest':['cricket','football','chess','cooking']
}
df=pd.DataFrame(data)
print(df)
print(df.mean(numeric_only=True))
# Out:
#      Name  Age  interest
# 0  Aditya   12   cricket
# 1   Virat   13  football
# 2  Krishu   14     chess
# 3    Mahi   15   cooking
# Age    13.5
# dtype: float64
